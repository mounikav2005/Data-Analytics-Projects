# %% [markdown]
# <a href="https://colab.research.google.com/github/Taj1920/Data_Analysis/blob/main/Population_analysis/world_population_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![population.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # World Population Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('population.xlsx')
df
# Out:
#        LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0        4.0          Afghanistan  2030.0    0-4          0.0         5.0
# 1        8.0              Albania  2030.0    0-4          0.0         5.0
# 2       12.0              Algeria  2030.0    0-4          0.0         5.0
# 3       24.0               Angola  2030.0    0-4          0.0         5.0
# 4       28.0  Antigua and Barbuda  2030.0    0-4          0.0         5.0
# ...      ...                  ...     ...    ...          ...         ...
# 45971  308.0              Grenada  2040.0   100+        100.0        -1.0
# 45972  426.0              Lesotho  2040.0   100+        100.0        -1.0
# 45973  516.0              Namibia  2040.0   100+        100.0        -1.0
# 45974  690.0           Seychelles  2040.0   100+        100.0        -1.0
# 45975  776.0                Tonga  2040.0   100+        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# 0      3020.571   2871.955  5892.526
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45976 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  float64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  float64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.2+ MB

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45969 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  float64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  float64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.5+ MB

# %%
#Changing the Data type of LocID into int
df['LocID']=df['LocID'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45969 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  int64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  float64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.5+ MB

# %%
#Changing the Data type of Time col into int
df['Time']=df['Time'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45969 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  int64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  int64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 3.5+ MB

# %%
#Changing the Data type of AgeGrpStart col into int
df['AgeGrpStart']=df['AgeGrpStart'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45969 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  int64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  int64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  int64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 3.5+ MB

# %%
#Removing unwanted data in PopMale 'ERROR_6.246'

df['PopMale']=df['PopMale'].str.strip('ERROR_')

#Changing the Data type of popmale PopFemale col into int
df['PopMale']=df['PopMale'].astype(float)
df['PopMale']=df['PopMale'].astype(int)
df['PopFemale']=df['PopFemale'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45969 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  int64
#  1   Location     45969 non-null  object
#  2   Time         45969 non-null  int64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  int64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  int64
#  7   PopFemale    45969 non-null  int64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# **Visualizing Total Population By Location**

# %%
loc=df.groupby('Location')['PopTotal'].sum().sort_values(ascending=False)
loc=pd.DataFrame(loc).iloc[:7,:]
plt.figure(figsize=(12,5))
a=sns.barplot(x='Location',y='PopTotal',data=loc,hue='Location',palette='plasma',errorbar=None)
a.set_xlabel('Location',fontsize=13,color='green')
a.set_ylabel('Total Population',fontsize=13,color='green')
def data_label(a):
  for i in a.containers:
    a.bar_label(i)

data_label(a)

# %% [markdown]
# Total population of India and China is more compared to other locations

# %% [markdown]
# # Visualizing Population male and female by Location

# %%
pop=df.pivot_table(values=['PopMale','PopFemale'],index='Location',aggfunc='sum')
pop.sort_values(by='PopMale',ascending=False,inplace=True)
pop=pop.iloc[:7,:]

fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,5))
a=sns.barplot(x='Location',y='PopMale',hue='Location',data=pop,palette='plasma',ax=axes[0])

b=sns.barplot(x='Location',y='PopFemale',hue='Location',data=pop,palette='plasma',ax=axes[1])
axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation=90)
axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation=90)
data_label(a)
data_label(b)
plt.show()
# Out:
# <ipython-input-93-945bf55a66f3>:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(axes[0].get_xticklabels(),rotation=90)
# <ipython-input-93-945bf55a66f3>:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(axes[1].get_xticklabels(),rotation=90)

# %% [markdown]
# Male and Female population is more in India and China compared to other locations

# %% [markdown]
# **Visualizing Total Population by AgeGrp**

# %%
age=df.groupby(['AgeGrp'])['PopTotal'].sum().sort_values(ascending=False)
age=pd.DataFrame(age).iloc[:7,:]
# plt.figure(figsize=(17,5))
# a=sns.barplot(x='AgeGrp',y='PopTotal',hue='AgeGrp',data=age,palette='plasma')
# for i in a.containers:
#   a.bar_label(i,label_type='center',rotation=90)

plt.pie(age['PopTotal'],labels=['0-4','5-9','10-14','15-19','20-24','25-29','30-34'],autopct='%0.0f%%')
plt.show()

# %% [markdown]
# Population Under Age group 0-4,5-9,10-14, 15-19 is more compared to other age groups

# %%
time=df.groupby('Time')['PopTotal'].sum()
time=pd.DataFrame(time).reset_index()
plt.figure(figsize=(17,5))
a=sns.lineplot(x='Time',y='PopTotal',data=time,marker='o',markersize=8,markerfacecolor='orange',markeredgecolor='orange')
for i,j in zip(time['Time'],time['PopTotal']):
  plt.annotate(f'{i},{j}',(i,j),ha='left')

# %% [markdown]
# Total Population over Time is Increasing

# %% [markdown]
# # Conclusion:
# # 1. Total Population in India and china is more.
# #2. People under the age groups 0-4,5-9,10-14, 15-19 are more.
# #3. Population is increasing over Time.
